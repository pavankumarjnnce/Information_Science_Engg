# %% [markdown]
# <a href="https://colab.research.google.com/github/pavankumarjnnce/Information_Science_Engg/blob/main/RobertEDGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from skimage import filters
import skimage

# %%
image = cv2.imread("Coin.PNG", 0)
plt.figure(figsize=(8, 8))
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
#Applying Sobel Edge operator

sobel_image = filters.sobel(image)


# cmap while displaying is not changed to gray for better visualisation
plt.figure(figsize=(8, 8))
plt.imshow(sobel_image)
plt.axis("off")
plt.show()

# %%
image = cv2.imread("Coin.PNG", 0)
plt.figure(figsize=(8, 8))
plt.imshow(image)
plt.axis("off")
plt.show()

#Applying Roberts Edge operator

roberts_image = filters.roberts(image)


# cmap while displaying is not changed to gray for better visualisation
plt.figure(figsize=(8, 8))
plt.imshow(roberts_image)
plt.axis("off")
plt.show()

# %%
prewitt_image = filters.prewitt(image)


# cmap while displaying is not changed to gray for better visualisation
plt.figure(figsize=(8, 8))
plt.imshow(prewitt_image)
plt.axis("off")
plt.show()
