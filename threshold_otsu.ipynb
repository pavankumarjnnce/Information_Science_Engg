# %% [markdown]
# <a href="https://colab.research.google.com/github/pavankumarjnnce/Information_Science_Engg/blob/main/threshold_otsu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
image = cv2.imread("Capture.PNG", 0)


plt.figure(figsize=(8, 8))
plt.imshow(image, cmap="gray")
plt.axis("off")
plt.show()

# %%
flattened_image = image.reshape((image.shape[0] * image.shape[1],))

# %% [markdown]
# # New Section

# %%
flattened_image.shape
# Out:
# (121792,)

# %%
plt.figure()
sns.distplot(flattened_image, kde=True)
plt.show()

# %%
#Applying Otsu Thresholding to the image for segmentation

ret, thresh1 = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# %%
plt.figure(figsize=(8, 8))
plt.imshow(thresh1, cmap="binary")
plt.axis("off")
plt.show()
